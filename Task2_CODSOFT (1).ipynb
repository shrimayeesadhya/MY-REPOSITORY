# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_movie = pd.read_csv('/content/IMDb Movies India.csv',encoding='Latin-1' )
df_movie.dropna(inplace=True)
df_movie.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_movie.shape
# Out:
# (5659, 10)

# %%
df_movie.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_movie.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
 import pandas as pd

df_movie = pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1', sep=',')

df_movie.dropna(inplace=True)
df_movie.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_ratings = pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1', sep=',')
df_ratings.dropna(inplace=True)
df_ratings.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_ratings.shape
# Out:
# (5659, 10)

# %%
df_ratings.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_users=pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1', sep=',')
df_users.dropna(inplace=True)
df_users.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
df_users.shape
# Out:
# (5659, 10)

# %%
df_users.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_users=pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1', sep=',')
df_users.dropna(inplace=True)
df_users.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder=LabelEncoder()
df_users['Genre']=LabelEncoder.fit_transform(df_users['Genre'])
df_users.head()
# Out:
#                                  Name    Year Duration  Genre  Rating  Votes  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min    229     7.0      8
# 3                             #Yaaram  (2019)  110 min    184     4.4     35
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min    157     4.7    827
# 6                           ...Yahaan  (2005)  142 min    289     7.4  1,086
# 8                  ?: A Question Mark  (2012)   82 min    320     5.6    326
#
#          Director          Actor 1                 Actor 2          Actor 3
# 1   Gaurav Bakshi     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3      Ovais Khan          Prateik              Ishita Raj  Siddhant Kapoor
# 5    Rahul Rawail       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Shoojit Sircar  Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8   Allyson Patel        Yash Dave          Muntazir Ahmad     Kiran Bhatia

# %%
df_users.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_data=pd.concat([df_movie,df_ratings,df_users],axis=1)
df_data.dropna()
df_data.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
df_data.shape
# Out:
# (5659, 30)

# %%
df2=df_data.drop(["Actor 1","Actor 2","Actor 3"],axis=1)
df2.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director  \
# 1                      Drama     7.0      8   Gaurav Bakshi
# 3            Comedy, Romance     4.4     35      Ovais Khan
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel
#
#                                  Name    Year Duration  ...  Rating  Votes  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min  ...     7.0      8
# 3                             #Yaaram  (2019)  110 min  ...     4.4     35
# ...

# %%
df2.describe()
# Out:
#             Rating       Rating        Genre       Rating
# count  5659.000000  5659.000000  5659.000000  5659.000000
# mean      5.898533     5.898533   171.728221     5.898533
# std       1.381165     1.381165   108.208770     1.381165
# min       1.100000     1.100000     0.000000     1.100000
# 25%       5.000000     5.000000    47.000000     5.000000
# 50%       6.100000     6.100000   184.000000     6.100000
# 75%       6.900000     6.900000   248.000000     6.900000
# max      10.000000    10.000000   375.000000    10.000000

# %%
df2.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# dtype: int64

# %%
df2_final=df2.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-be21f14c4a84> in <cell line: 1>()
# ----> 1 df_final=df.dropna()
#
# NameError: name 'df' is not defined

# %%
sns.countplot(x=df_final['Genre'],hue=df_final['rating'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-dd02130e7d04> in <cell line: 1>()
# ----> 1 sns.countplot(x=df_final['Genre'],hue=df_final['rating'])
#
# NameError: name 'df_final' is not defined
